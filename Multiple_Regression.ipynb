# %% [markdown]
# load data and store in dataframe df:

# %%
import pandas as pd
import random
from sklearn.linear_model import LinearRegression

# %%
# path of data 
path = 'Automobile_data.csv'
df = pd.read_csv(path, na_values = ["?"], keep_default_na = False) # all ? values will be Nulls
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df= df[pd.to_numeric(df["price"], errors='coerce').notnull()] # delete rows with Nulls
df= df[pd.to_numeric(df["horsepower"], errors='coerce').notnull()]

def gauss_with_mean(x):
    try:
        x = int(x)
        return x
    except ValueError:
        return  m + random.gauss(0,1)

# because normalized lossed has to many Nulls we will replace them with the mean value + some random deviation
    
m = df["normalized-losses"].mean()

df["normalized-losses"] = df["normalized-losses"].apply(gauss_with_mean)

# %%
df.reset_index(inplace = True)

# %%
df.head(n = 10)
# Out:
#    index  symboling  normalized-losses         make fuel-type aspiration  \
# 0      0          3         121.123619  alfa-romero       gas        std
# 1      1          3         123.327872  alfa-romero       gas        std
# 2      2          1         122.876431  alfa-romero       gas        std
# 3      3          2         164.000000         audi       gas        std
# 4      4          2         164.000000         audi       gas        std
# 5      5          2         121.385571         audi       gas        std
# 6      6          1         158.000000         audi       gas        std
# 7      7          1         123.927483         audi       gas        std
# 8      8          1         158.000000         audi       gas      turbo
# 9     10          2         192.000000          bmw       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 0          two  convertible          rwd           front  ...          130
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
size = int(0.2 * df.shape[0])

# %%
test_database = pd.DataFrame() # lets create a test set and a training set manually

# %%
test_database
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
seen = set()
to_drop = []
while size:
    ind = random.randint(min(df.index), max(df.index))
    #print(ind)
    while ind in seen:
        ind = random.randint(min(df.index), max(df.index))
    seen.add(ind)
    to_drop.append(ind)
    row = df.iloc[ind]
    test_database = pd.concat([test_database, pd.DataFrame([row])])
    size -= 1
else:
    df.drop(to_drop, inplace = True)

# %%
test_database.reset_index(inplace = True)
df.reset_index(inplace = True)

# %%
df.head(n = 10)
# Out:
#    level_0  index  symboling  normalized-losses         make fuel-type  \
# 0        0      0          3         121.123619  alfa-romero       gas
# 1        1      1          3         123.327872  alfa-romero       gas
# 2        2      2          1         122.876431  alfa-romero       gas
# 3        3      3          2         164.000000         audi       gas
# 4        4      4          2         164.000000         audi       gas
# 5        5      5          2         121.385571         audi       gas
# 6        6      6          1         158.000000         audi       gas
# 7        7      7          1         123.927483         audi       gas
# 8        8      8          1         158.000000         audi       gas
# 9        9     10          2         192.000000          bmw       gas
#
#   aspiration num-of-doors   body-style drive-wheels  ... engine-size  \
# 0        std          two  convertible          rwd  ...         130
# ...

# %%
test_database.head(n = 10)
# Out:
#    level_0  index  symboling  normalized-losses           make fuel-type  \
# 0      145    151          1          87.000000         toyota       gas
# 1      172    178          3         197.000000         toyota       gas
# 2      178    184          2          94.000000     volkswagen    diesel
# 3       36     37          0         106.000000          honda       gas
# 4      112    115          0         161.000000         peugot       gas
# 5       27     28         -1         110.000000          dodge       gas
# 6       63     66          0         121.766046          mazda    diesel
# 7       31     32          1         101.000000          honda       gas
# 8       64     67         -1          93.000000  mercedes-benz    diesel
# 9       60     63          0         121.216672          mazda    diesel
#
#   aspiration num-of-doors body-style drive-wheels  ... engine-size  \
# 0        std          two  hatchback          fwd  ...          92
# ...

# %%
X = df[["horsepower", "curb-weight", "engine-size", "highway-mpg"]]
Y = df[['price']]

# %%
lm.fit(X, Y)
# Out:
# LinearRegression()

# %%
X = test_database[["horsepower", "curb-weight", "engine-size", "highway-mpg"]]
Y = test_database[['price']]

# %%
Yha =lm.predict(X)
Yha[0:5]
# Out:
# array([[ 5710.30741416],
#        [21936.21109337],
#        [ 6197.99183863],
#        [ 9480.24718817],
#        [14691.48123975]])

# %%
Y.head() # predictions are not perfect, but relatively close
# Out:
#      price
# 0   6338.0
# 1  16558.0
# 2   7995.0
# 3   7895.0
# 4  16630.0

# %%
lm.score(X,Y) # R**2
# Out:
# 0.7940336324890291

# %%
lm.intercept_ # intercept
# Out:
# array([-12231.33017938])

# %%
lm.coef_ # coefficents
# Out:
# array([[ 55.88920659,   4.14697557,  79.96806301, -35.27329403]])

# %% [markdown]
# Equation:

# %% [markdown]
# Y = 55.88920659 * x1 + 4.14697557 * x2 + 79.96806301 * x3 -35.27329403 * x4 -12231.33017938

# %%
X = df[["normalized-losses","highway-mpg"]]
Y = df[['price']]

# %%
lm2=LinearRegression() # second model
lm2
# Out:
# LinearRegression()

# %%
lm2.fit(X,Y) # train the model
# Out:
# LinearRegression()

# %%
X = test_database[["normalized-losses","highway-mpg"]]
Y = test_database[['price']]

# %%
Yha =lm2.predict(X)
Yha[0:5]
# Out:
# array([[ 6690.67757276],
#        [18575.00055078],
#        [ -207.0027177 ],
#        [10966.04526129],
#        [18629.95540632]])

# %%
Y.head()
# Out:
#      price
# 0   6338.0
# 1  16558.0
# 2   7995.0
# 3   7895.0
# 4  16630.0

# %%
lm2.coef_ #coefficents
# Out:
# array([[  -1.52652377, -860.87432801]])

# %%
lm2.intercept_ # intercept
# Out:
# array([39536.70960484])

# %%
lm2.score(X,Y) # R**2
# Out:
# 0.44787248702635507

# %% [markdown]
# Equation

# %% [markdown]
# Y = -1.52652377*x1 - 860.87432801 *x2 + 34314.44215086

# %% [markdown]
# Note that if you run the file again, all models will be different! This is because we randomly chose test and train sets, and we do not have a lot of data here, so these changes affect the models signifficantly. In such case it is probably better to either add more data or use k-folds to have a better estimation of our equations
